# %%
import math

import numpy as np
import pandas as pd

import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
from string import punctuation

# %%
translit = pd.read_csv('translit.csv')
translit
# Out:
#    Национальный знак Рекомендуемая транслитерация
# 0                  А                            A
# 1                  Б                            B
# 2                  В                            V
# 3                  Г                            G
# 4                  Д                            D
# 5                  Е                            E
# 6                  Ё                            E
# 7                  Ж                           ZH
# 8                  З                            Z
# 9                  И                            I
# 10                 Й                            I
# 11                 К                            K
# 12                 Л                            L
# 13                 М                            M
# 14                 Н                            N
# 15                 О                            O
# 16                 П                            P
# 17                 Р                            R
# ...

# %%
translit['Национальный знак'].to_list()
# Out:
# ['А',
#  'Б',
#  'В',
#  'Г',
#  'Д',
#  'Е',
#  'Ё',
#  'Ж',
#  'З',
#  'И',
#  'Й',
#  'К',
#  'Л',
#  'М',
#  'Н',
#  'О',
#  'П',
#  'Р',
#  'С',
#  'Т',
#  'У',
#  'Ф',
#  'Х',
#  'Ц',
#  'Ч',
#  'Ш',
#  'Щ',
#  'Ы',
#  'Ъ',
#  'Э',
#  'Ю',
#  'Я']

# %%
translit['Национальный знак'].to_list().index('Ф')
# Out:
# 21

# %%
translit['Рекомендуемая транслитерация'].to_list()[translit['Национальный знак'].to_list().index('Ф')]
# Out:
# 'F'

# %%
string = 'Никифоров Иоанн,, Леонидович'


new_string = ''
for x in string:
    if x.upper() in translit['Национальный знак'].to_list():
        new_string += translit['Рекомендуемая транслитерация'].to_list()[translit['Национальный знак'].to_list().index(x.upper())]
    else:
        new_string += x
print(new_string)
# Out:
# NIKIFOROV IOANN,, LEONIDOVICH
